# %%
import requests
import os
from dotenv import load_dotenv
load_dotenv()
import pandas as pd
import folium

# %%
df_1500 = pd.read_csv("for_api_1500.csv")
display(df.head(12))
print(df.shape)
# Out:
#     Unnamed: 0                       _id category_code country_code  \
# 0          210  5d277baf5370f8e6fc94d96c   games_video          USA
# 1           53  5d277baf5370f8e6fc94d8cf   advertising          USA
# 2          189  5d277baf5370f8e6fc94d957      software          USA
# 3          125  5d277baf5370f8e6fc94d917   advertising          USA
# 4           78  5d277baf5370f8e6fc94d8e8   advertising          USA
# 5          206  5d277baf5370f8e6fc94d968      software          GBR
# 6           20  5d277baf5370f8e6fc94d8ae           web          USA
# 7           24  5d277baf5370f8e6fc94d8b2           web          USA
# 8           88  5d277baf5370f8e6fc94d8f2        design          DEU
# 9          196  5d277baf5370f8e6fc94d95e           web          USA
# 10          27  5d277baf5370f8e6fc94d8b5   advertising          USA
# 11          85  5d277baf5370f8e6fc94d8ef           web          USA
#
#     founded_year                                             geoloc  \
# 0           2008  {'type': 'Point', 'coordinates': [-71.0680027,...
# 1           2006  {'type': 'Point', 'coordinates': [-122.245087,...
# 2           2003  {'type': 'Point', 'coordinates': [-121.970505,...
# 3           2008  {'type': 'Point', 'coordinates': [-122.4011706...
# 4           2004  {'type': 'Point', 'coordinates': [-73.984268, ...
# 5           2005  {'type': 'Point', 'coordinates': [-1.4629301, ...
# 6           2006  {'type': 'Point', 'coordinates': [-122.39071, ...
# 7           2004  {'type': 'Point', 'coordinates': [-122.0727749...
# 8           2008  {'type': 'Point', 'coordinates': [13.4469031, ...
# 9           2004  {'type': 'Point', 'coordinates': [-122.3927145...
# 10          2005  {'type': 'Point', 'coordinates': [-122.39323, ...
# 11          2006  {'type': 'Point', 'coordinates': [-73.7258199,...
#
#      latitude   longitude           name  number_of_employees  \
# 0   42.340653  -71.068003         SCVNGR                   60
# 1   37.530893 -122.245087         MyBuys                  120
# 2   37.382137 -121.970505  Packet Design                   60
# 3   37.791119 -122.401171           Bizo                   66
# 4   40.743662  -73.984268     MediaTrust                   60
# 5   53.380011   -1.462930       WANdisco                  175
# 6   37.779507 -122.390710     Eventbrite                  200
# 7   37.392798 -122.072775           IMVU                  150
# 8   52.498620   13.446903      99designs                  100
# 9   37.788714 -122.392714  Double Fusion                   80
# 10  37.710677 -122.393230     Greystripe                   90
# 11  40.858752  -73.725820            OLX                   85
#
#    total_money_raised  total_offices  nearest_offices  ranking
# 0              $40.8M              1               27     13.5
# 1              $40.8M              2               27     13.5
# 2               $2.8M              1               27     13.5
# 3              $28.5M              1               27     13.5
# 4                $21M              1               27     13.5
# 5                $45M              2               27     13.5
# 6               $140M              1               27     13.5
# 7                $29M              1               27     13.5
# 8                $35M              3               27     13.5
# 9                $59M              1               27     13.5
# 10             $17.6M              1               27     13.5
# 11             $28.5M              1               27     13.5
# (239, 14)

# %%
# We apply filter to reduce number of companies.
# As we consider the most importat the number of near companies, employees and and year, we filter for its first 10

# %%
df_1500_api = df_1500.head(10)

# %%
df_1500_api.reset_index(inplace = True)

# %%
"""taxi_stand
train_station
transit_station
subway_station
bus_station
"""
def ranking_places(col):
    rank_scores = {"nearest_offices": 0.8, "total_money_raised": 0.7, "number_of_employees": 0.7, "meetups": 0.6, 
                   "nursery": 0.3, "gym": 0.3}
    match = []
    for i in range(len(col)):
        match.append(rank_scores.get(col[i]) * rank_scores.value[i])
    return match

# %%
df_1500_api.head(15)
# Out:
#    level_0  Unnamed: 0  index                       _id category_code  \
# 0        0           0     51  5d277baf5370f8e6fc94d8cd    enterprise
# 1        1           1     20  5d277baf5370f8e6fc94d8ae           web
# 2        2           2    167  5d277baf5370f8e6fc94d941    enterprise
# 3        3           3     26  5d277baf5370f8e6fc94d8b4    enterprise
# 4        4           4    190  5d277baf5370f8e6fc94d958   advertising
# 5        5           5    136  5d277baf5370f8e6fc94d922   advertising
# 6        6           6    165  5d277baf5370f8e6fc94d93f      software
# 7        7           7     85  5d277baf5370f8e6fc94d8ef           web
# 8        8           8    164  5d277baf5370f8e6fc94d93e           web
# 9        9           9     27  5d277baf5370f8e6fc94d8b5   advertising
#
#   country_code  founded_year  \
# 0          USA          2006
# 1          USA          2006
# 2          USA          2004
# 3          USA          2004
# 4          USA          2006
# 5          SWE          2007
# 6          USA          2005
# 7          USA          2006
# 8          USA          2006
# 9          USA          2005
#
#                                               geoloc   latitude   longitude  \
# 0  {'type': 'Point', 'coordinates': [-122.158804,...  37.439380 -122.158804
# 1  {'type': 'Point', 'coordinates': [-122.39071, ...  37.779507 -122.390710
# 2  {'type': 'Point', 'coordinates': [-121.967223,...  37.369445 -121.967223
# 3  {'type': 'Point', 'coordinates': [-104.988123,...  39.755092 -104.988123
# 4  {'type': 'Point', 'coordinates': [-105.278785,...  40.058448 -105.278785
# 5  {'type': 'Point', 'coordinates': [18.0333601, ...  59.335183   18.033360
# 6  {'type': 'Point', 'coordinates': [-122.161287,...  37.444098 -122.161287
# 7  {'type': 'Point', 'coordinates': [-73.7258199,...  40.858752  -73.725820
# 8  {'type': 'Point', 'coordinates': [-111.643179,...  40.250096 -111.643179
# 9  {'type': 'Point', 'coordinates': [-122.39323, ...  37.710677 -122.393230
#
#               name  number_of_employees total_money_raised  total_offices  \
# 0            Gigya                  230             $69.8M              1
# 1       Eventbrite                  200              $140M              1
# 2           Apigee                   65              $107M              1
# 3        NewsGator                   90             $39.3M              1
# 4           Intela                   70             $13.3M              4
# 5       Videoplaza                   70             €15.9M              5
# 6  Nexenta Systems                  200             $49.9M              1
# 7              OLX                   85             $28.5M              1
# 8       FamilyLink                   60             $3.65M              1
# 9       Greystripe                   90             $17.6M              1
#
#    nearest_offices
# 0               27
# 1               27
# 2               27
# 3               27
# 4               27
# 5               27
# 6               27
# 7               27
# 8               27
# 9               27

# %%
PLACES_KEY = os.environ["PLACES_KEY"]


output_file = "json"
radius = "1500"
type_= "restaurant"
keywords = "hamburguers"
lst_restau = []

for i in range(len(df_1500_api)):
    coor = df_1500_api["latitude"][i].astype(str) + ", " + df_1500_api["longitude"][i].astype(str)
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/"+ output_file +"?location="+coor +"&radius=" +radius+ "&type="+type_+"&keyword="+keywords + "&key="+ PLACES_KEY
    res = requests.get(url)
    data = res.json()
    lst_restau.append(len(data))

# %%
print(lst_restau)
len(lst_restau)
df_1500_api["num_restaurants"] = lst_restau
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# /home/slimbook/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_1500_api.head(10)
# Out:
#    level_0  Unnamed: 0  index                       _id category_code  \
# 0        0           0     51  5d277baf5370f8e6fc94d8cd    enterprise
# 1        1           1     20  5d277baf5370f8e6fc94d8ae           web
# 2        2           2    167  5d277baf5370f8e6fc94d941    enterprise
# 3        3           3     26  5d277baf5370f8e6fc94d8b4    enterprise
# 4        4           4    190  5d277baf5370f8e6fc94d958   advertising
# 5        5           5    136  5d277baf5370f8e6fc94d922   advertising
# 6        6           6    165  5d277baf5370f8e6fc94d93f      software
# 7        7           7     85  5d277baf5370f8e6fc94d8ef           web
# 8        8           8    164  5d277baf5370f8e6fc94d93e           web
# 9        9           9     27  5d277baf5370f8e6fc94d8b5   advertising
#
#   country_code  founded_year  \
# 0          USA          2006
# 1          USA          2006
# 2          USA          2004
# 3          USA          2004
# 4          USA          2006
# 5          SWE          2007
# 6          USA          2005
# 7          USA          2006
# 8          USA          2006
# 9          USA          2005
#
#                                               geoloc   latitude   longitude  \
# 0  {'type': 'Point', 'coordinates': [-122.158804,...  37.439380 -122.158804
# 1  {'type': 'Point', 'coordinates': [-122.39071, ...  37.779507 -122.390710
# 2  {'type': 'Point', 'coordinates': [-121.967223,...  37.369445 -121.967223
# 3  {'type': 'Point', 'coordinates': [-104.988123,...  39.755092 -104.988123
# 4  {'type': 'Point', 'coordinates': [-105.278785,...  40.058448 -105.278785
# 5  {'type': 'Point', 'coordinates': [18.0333601, ...  59.335183   18.033360
# 6  {'type': 'Point', 'coordinates': [-122.161287,...  37.444098 -122.161287
# 7  {'type': 'Point', 'coordinates': [-73.7258199,...  40.858752  -73.725820
# 8  {'type': 'Point', 'coordinates': [-111.643179,...  40.250096 -111.643179
# 9  {'type': 'Point', 'coordinates': [-122.39323, ...  37.710677 -122.393230
#
#               name  number_of_employees total_money_raised  total_offices  \
# 0            Gigya                  230             $69.8M              1
# 1       Eventbrite                  200              $140M              1
# 2           Apigee                   65              $107M              1
# 3        NewsGator                   90             $39.3M              1
# 4           Intela                   70             $13.3M              4
# 5       Videoplaza                   70             €15.9M              5
# 6  Nexenta Systems                  200             $49.9M              1
# 7              OLX                   85             $28.5M              1
# 8       FamilyLink                   60             $3.65M              1
# 9       Greystripe                   90             $17.6M              1
#
#    nearest_offices  num_restaurants
# 0               27                3
# 1               27                3
# 2               27                3
# 3               27                3
# 4               27                3
# 5               27                3
# 6               27                3
# 7               27                3
# 8               27                3
# 9               27                3

# %%
def points(col_lat, col_lon): #insert values as (df[col_lat], df[col_lon])
    statmad = df_1500_api[['latitude', 'longitude']]
    statmadlist = statmad.values.tolist()
    popup = df_1500_api[['name']]
    statmap = folium.Map(zoom_start=11) 
    for point in range(0, len(statmadlist)):
        folium.Marker(statmadlist[point], popup=popup.iloc[point,0]).add_to(statmap)
    return statmap    

points(df_1500_api['latitude'], df_1500_api['longitude'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
PLACES_KEY = os.environ["PLACES_KEY"]


output_file = "json"
radius = "1500"
type_= "school"
keywords = "nursery"
lst_nursery = []

for i in range(len(df_1500_api)):
    coor = df_1500_api["latitude"][i].astype(str) + ", " + df_1500_api["longitude"][i].astype(str)
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/"+ output_file +"?location="+coor +"&radius=" +radius+ "&type="+type_+"&keyword="+keywords + "&key="+ PLACES_KEY
    res = requests.get(url)
    data = res.json()
    lst_restau.append(len(data))
    
print(lst_restau)
len(lst_restau)
df_1500_api["school"] = lst_nursery
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-1885abc06fb1> in <module>
#      17 print(lst_restau)
#      18 len(lst_restau)
# ---> 19 df_1500_api["school"] = lst_nursery
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
coor = df["latitude"][0].astype(str) + ", " + df["longitude"][0].astype(str)
coor
# Out:
# '42.3406534, -71.0680027'

# %%
PLACES_KEY = os.environ["PLACES_KEY"]


output_file = "json"
location = "-33.8670522, 151.1957362"
radius = "1500"
type_= "restaurant"
keywords = "hamburguers"
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/"+ output_file +"?location="+coor +"&radius=" +radius+ "&type="+type_+"&keyword="+keywords + "&key="+ PLACES_KEY
res = requests.get(url)
data = res.json()
data
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 42.3496398,
#      'lng': -71.08155599999999},
#     'viewport': {'northeast': {'lat': 42.35108742989271,
#       'lng': -71.08026867010727},
#      'southwest': {'lat': 42.34838777010727, 'lng': -71.08296832989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '02951d28fd99fd3833fe1fc17331d67fcabbcc40',
#    'name': 'Shake Shack',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5312,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109900065306969516706/photos">Christa Bohan</a>'],
#      'photo_reference': 'CmRaAAAA01Iv12Mf9p2NUIc1P2h32jjaLynaVWFYiQQyyNRxAWRxg1ebgJZbNSNUkak-9jCiYOVHoIngIxFDFOYw0GCkaMald1ceg-CTGsyHsPN2CtWVQMKgcuKztIouu_H5z5HTEhCngGC55NvlxK7tikbxImmRGhQN7JM78SInS5YJnwx2nLZW3Y0cjA',
#      'width': 2988}],
#    'place_id': 'ChIJk8w38A5644kRkJggBF-ITts',
#    'plus_code': {'compound_code': '8WX9+V9 Boston, Massachusetts',
#     'global_code': '87JC8WX9+V9'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJk8w38A5644kRkJggBF-ITts',
#    'scope': 'GOOGLE',
#    'types': ['restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1984,
#    'vicinity': '234-236 Newbury St, Boston'},
#   {'geometry': {'location': {'lat': 42.3556834, 'lng': -71.0626996},
#     'viewport': {'northeast': {'lat': 42.35705752989271,
#       'lng': -71.06139592010727},
#      'southwest': {'lat': 42.35435787010727, 'lng': -71.06409557989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '1c2ec429670fab0943dc0aed82c8d58395a977c5',
#    'name': 'MOOYAH Burgers, Fries & Shakes',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114699778214786234782/photos">Ken P.</a>'],
#      'photo_reference': 'CmRaAAAACJ0UgYox42zQCRy_2NPr_aSTUaGb43KdgC7AdasLWPVnsuWq6gzpeKv4g1ubVrLgYoC1PV_AQHMfpjSVAoF7hZFORJBbjurp5RnQT_CL_HMpdYKx7tQxr3sjy9etJa5hEhAkUuMZpzurKXgui9EILep1GhQ-v991QqzkygEhf2hXO-MajbDipQ',
#      'width': 2340}],
#    'place_id': 'ChIJUWI_2Zxw44kRZc0rMgOGXAk',
#    'plus_code': {'compound_code': '9W4P+7W Boston, Massachusetts',
#     'global_code': '87JC9W4P+7W'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJUWI_2Zxw44kRZc0rMgOGXAk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 491,
#    'vicinity': '140 Tremont St, Boston'},
#   {'geometry': {'location': {'lat': 42.3468102, 'lng': -71.08847329999999},
#     'viewport': {'northeast': {'lat': 42.34829667989273,
#       'lng': -71.08716527010728},
#      'southwest': {'lat': 42.34559702010728, 'lng': -71.08986492989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'de22a62cc5864d135bba792edc960171ec029a0c',
#    'name': 'Boston Burger Co-Boylston',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110864150395489759661/photos">shivam gupta</a>'],
#      'photo_reference': 'CmRaAAAA1aEI_M4HAsQQoMoUdfjONLT9dUBa0iMkhnCiwf1MBykKRuo8aqRZzSeZpI-43MVyHwZY2uUgm3rX2lhPjC5Thcr91FzBZdXF6lUN7uKWe8iy8InVQeICzzo1dgr7sm-dEhCQJA6pVz9eRMMucI9XxWoiGhSBW4ltKg87RLR--mmz-YSipDNYpw',
#      'width': 1960}],
#    'place_id': 'ChIJwRxfIBt644kRuDR56soOZ1o',
#    'plus_code': {'compound_code': '8WW6+PJ Boston, Massachusetts',
#     'global_code': '87JC8WW6+PJ'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJwRxfIBt644kRuDR56soOZ1o',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1568,
#    'vicinity': '1100 Boylston St, Boston'},
#   {'geometry': {'location': {'lat': 42.3543199, 'lng': -71.0587449},
#     'viewport': {'northeast': {'lat': 42.35563597989272,
#       'lng': -71.05743872010727},
#      'southwest': {'lat': 42.35293632010728, 'lng': -71.06013837989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '04db72825c18e2ab253a20ae015b0a48b61156b1',
#    'name': 'Five Guys',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115335301241385962806/photos">선우진</a>'],
#      'photo_reference': 'CmRaAAAA0O9NZIGg8VQT1S_RBw_ny6A15YhrxWOwaV9cwM4AnujNojyoFDCDqTl5eLVCn0XKZaP9xmQNa9e4gWxYRojzrfcCAwPPa6Tq0oFSR-sQs_6oD0f58zLC9y4Xj39artBbEhAidIco4C-4VCcLnLwgEVO7GhTUedbZ8b_oE47mYgbq_cHzKrBiVg',
#      'width': 3024}],
#    'place_id': 'ChIJbTWx-YJw44kR0FCQuzjIMIc',
#    'plus_code': {'compound_code': '9W3R+PG Boston, Massachusetts',
#     'global_code': '87JC9W3R+PG'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJbTWx-YJw44kR0FCQuzjIMIc',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1300,
#    'vicinity': '58 Summer St, Boston'},
#   {'geometry': {'location': {'lat': 42.3541027, 'lng': -71.0589928},
#     'viewport': {'northeast': {'lat': 42.35551612989273,
#       'lng': -71.05755022010727},
#      'southwest': {'lat': 42.35281647010729, 'lng': -71.06024987989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'b2552d75e250ed3a341e14cc634ed725820625f5',
#    'name': "Wendy's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 250,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113260580852621186611/photos">Wendy&#39;s</a>'],
#      'photo_reference': 'CmRaAAAAnz3adMWpufllHgjHwfaF9n_Y-uXVUHFlCOZ8ov2gP3-huVcCUhQkcHCml4Lh6Pe1J6rbUx15mo3n4qe24iQVKGueqAXOa6XPh8rndM0ngBQ7ElHXrVHp1O2p-yvGKyFXEhBdj2_J0JCrj3UZTUCdJm6vGhTAxGyJAnv7wuFSM22OI7_MI9ZD5w',
#      'width': 250}],
#    'place_id': 'ChIJ57ufcINw44kReYAE3Z9JZXM',
#    'plus_code': {'compound_code': '9W3R+JC Boston, Massachusetts',
#     'global_code': '87JC9W3R+JC'},
#    'price_level': 1,
#    'rating': 3.9,
#    'reference': 'ChIJ57ufcINw44kReYAE3Z9JZXM',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 684,
#    'vicinity': '71 Summer St, Boston'},
#   {'geometry': {'location': {'lat': 42.34727729999999, 'lng': -71.0755983},
#     'viewport': {'northeast': {'lat': 42.34856887989272,
#       'lng': -71.07438082010727},
#      'southwest': {'lat': 42.34586922010728, 'lng': -71.07708047989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'c7b016e9a657a74fad6d9812ebf6930424697d8c',
#    'name': 'Tasty Burger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115452835152814264802/photos">ΓΕΩΡΓΙΟΣ ΟΙΚΟΝΟΜΟΥ</a>'],
#      'photo_reference': 'CmRaAAAAVSyi1Q23AwdcbqFju9vp3pvE8FyVCURYA4pt8VaOMpg-m2FRVegb9FyokJ4WaU9iEZqk7Rp2V7eSz_HwDUvEU34u9RHOecfqoYdsRuyKL4dDCj0Ll4Rfsf5xvVJlPQAuEhDam-w8CYClPFSvk1AvDPamGhSgA8Rymxi6ZovFdt0SxnQjS-PlmA',
#      'width': 3120}],
#    'place_id': 'ChIJKWxOPQ1644kRsYVD6ggoJ54',
#    'plus_code': {'compound_code': '8WWF+WQ Boston, Massachusetts',
#     'global_code': '87JC8WWF+WQ'},
#    'price_level': 1,
#    'rating': 4.1,
#    'reference': 'ChIJKWxOPQ1644kRsYVD6ggoJ54',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 871,
#    'vicinity': '145 Dartmouth St, Boston'},
#   {'geometry': {'location': {'lat': 42.3421982, 'lng': -71.0860859},
#     'viewport': {'northeast': {'lat': 42.34349437989272,
#       'lng': -71.08465537010727},
#      'southwest': {'lat': 42.34079472010728, 'lng': -71.08735502989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '2981783f97189b1e48cea3f3f1eee8a04c08cd27',
#    'name': 'Five Guys',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104747968418981395324/photos">Ross Hill</a>'],
#      'photo_reference': 'CmRaAAAA-2ll1QGtQXfww6m57mJ8lAf32V1ymL48E5Zg7gRqVRwsMeqW9au5A4mwqvDEQUiGoelVjfp5eey84w5pIAwTY8y9-7HQXJTS9cPWrjDh5j6FgfD0Dn5Hr-720usGhBm1EhBUIIl4di_BS7scOXs8nEJ4GhSmQpK3MQhr81JmoVpEgI_SvOF55g',
#      'width': 2160}],
#    'place_id': 'ChIJZUVq5Rl644kRBcXolcTvKrs',
#    'plus_code': {'compound_code': '8WR7+VH Boston, Massachusetts',
#     'global_code': '87JC8WR7+VH'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJZUVq5Rl644kRBcXolcTvKrs',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 627,
#    'vicinity': '263 Huntington Ave, Boston'},
#   {'geometry': {'location': {'lat': 42.3315446, 'lng': -71.07036350000001},
#     'viewport': {'northeast': {'lat': 42.33292232989272,
#       'lng': -71.06895762010728},
#      'southwest': {'lat': 42.33022267010728, 'lng': -71.07165727989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '87b6c12694f27f810306ae9433928cd2d83b129d',
#    'name': "McDonald's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 768,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103696704402200482176/photos">McDonald&#39;s</a>'],
#      'photo_reference': 'CmRaAAAAu-DkGXQpsI4j2rpNxRFO8WY1tDQK8jSsm2boD3aGLMejo4Cyg1J8z1pRbXKzH2MWhzKeX4fTx5AQuLf9FtE0QrtkNDyyW85IHq29wYx9as5-vYUSYwsGkOiBDC6yJc3dEhCofmLNWzd9gVIBG0YUizwTGhQoxYNKALKsGfPG1t5HonYMG2bCRQ',
#      'width': 1025}],
#    'place_id': 'ChIJaeYsIUF644kRXPIC1cnluXg',
#    'plus_code': {'compound_code': '8WJH+JV Boston, Massachusetts',
#     'global_code': '87JC8WJH+JV'},
#    'price_level': 1,
#    'rating': 2.9,
#    'reference': 'ChIJaeYsIUF644kRXPIC1cnluXg',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1572,
#    'vicinity': '870 Massachusetts Ave, Boston'},
#   {'geometry': {'location': {'lat': 42.3517081, 'lng': -71.0556466},
#     'viewport': {'northeast': {'lat': 42.35299177989272,
#       'lng': -71.05443862010728},
#      'southwest': {'lat': 42.35029212010728, 'lng': -71.05713827989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd388ebacdeb01b3aa9aa79251b50396ff11b756d',
#    'name': "McDonald's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 906,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117201291069496221774/photos">McDonald&#39;s</a>'],
#      'photo_reference': 'CmRaAAAAekWPC4udu3xpZUS1oGnfEHboeVetyulx51q3M-gKvWGEUzj6HHL38eLppEZNyVISBjaU0GCKdD8Og-bkhKv3qW60t9OJM1Or0UPmdBTpQ32qrkpnY7_bAHDkUuw2S9S6EhDL_xBZy-oqEDq2takRf82wGhSVP-iYEE2cEPPCB9AxmK97Auz-rA',
#      'width': 1920}],
#    'place_id': 'ChIJe645PYNw44kRoRr8XiXajtA',
#    'plus_code': {'compound_code': '9W2V+MP Boston, Massachusetts',
#     'global_code': '87JC9W2V+MP'},
#    'price_level': 1,
#    'rating': 2.7,
#    'reference': 'ChIJe645PYNw44kRoRr8XiXajtA',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 178,
#    'vicinity': '2 S Station, Boston'},
#   {'geometry': {'location': {'lat': 42.32519449999999, 'lng': -71.0618016},
#     'viewport': {'northeast': {'lat': 42.32644922989272,
#       'lng': -71.06050447010728},
#      'southwest': {'lat': 42.32374957010727, 'lng': -71.06320412989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'c06a5b948d2ffec9d85430222910973d2da85da5',
#    'name': 'Wahlburgers',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110627060005152366663/photos">Adetokunbo Anuwe</a>'],
#      'photo_reference': 'CmRaAAAA0NddSHNJqA_LruLevUZAWxXLCiBl9oh7vpAFIbOt2wDPQ5Oi0ToBDs660jRCNDwAFtQ4JPeFcBgqbCV4efWsjjntVw-QInYWmLxBopLp_ffXqgh05j2MgeytE-MAWal4EhA78Akk13tblbsHt3zURlfAGhQ_MrNIrVP0lTVa8t89qJGHxx8pBw',
#      'width': 3024}],
#    'place_id': 'ChIJuVTqTEV644kRjkbq_iZ2lkg',
#    'plus_code': {'compound_code': '8WGQ+37 Boston, Massachusetts',
#     'global_code': '87JC8WGQ+37'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJuVTqTEV644kRjkbq_iZ2lkg',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 252,
#    'vicinity': '9 District Avenue, Boston'},
#   {'geometry': {'location': {'lat': 42.3552225, 'lng': -71.0630429},
#     'viewport': {'northeast': {'lat': 42.35661577989272,
#       'lng': -71.06177427010728},
#      'southwest': {'lat': 42.35391612010728, 'lng': -71.06447392989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'be4e4ce5b3f8c5e7dcc2c062f513b3fd6b80ac8b',
#    'name': "McDonald's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 906,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104350085598605702289/photos">McDonald&#39;s</a>'],
#      'photo_reference': 'CmRaAAAAtodMwN4UvulAkm0wp7RYTvCUTkNdXfQLiR8usReHfiLxFRoK_Jv5XulQe94M7Y0R-pn4flxc1dghlkUHNupzVC03xCadoPaspsRnFOFUQ3m4sqef_VVI3gzN0904M4SDEhBlq9xLk0JeXk_Isxa-WFSSGhSN65pYCWzGzFGTkcGxOpwBYzoXYw',
#      'width': 1920}],
#    'place_id': 'ChIJe645PYNw44kR_0ilqhElTKw',
#    'plus_code': {'compound_code': '9W4P+3Q Boston, Massachusetts',
#     'global_code': '87JC9W4P+3Q'},
#    'price_level': 1,
#    'rating': 3.3,
#    'reference': 'ChIJe645PYNw44kR_0ilqhElTKw',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 734,
#    'vicinity': '146 Tremont St, Boston'},
#   {'geometry': {'location': {'lat': 42.3392229, 'lng': -71.0509402},
#     'viewport': {'northeast': {'lat': 42.34060667989272,
#       'lng': -71.04964552010728},
#      'southwest': {'lat': 42.33790702010727, 'lng': -71.05234517989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '5b53916a3b9f7af465a84b64f0b0d493d08ad995',
#    'name': 'Burger King',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1218,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105605086163823031818/photos">Burger King</a>'],
#      'photo_reference': 'CmRaAAAA7-s_XGTX-gLNnaARb6ZNrIEuxUKq6-9V_XN97I3irERdXe8Xmcgp-n0YVSVyUt7470-YtI3he9cLsyKZTNbw4qR3zbZrNgdic7jVIJOLrRbbvyhNBj53cRFnL3VsOweGEhBoOHxf_KtyTafnQVysySd5GhRUqG4XDuBE6prU4p_BV0dhnkOLbA',
#      'width': 1434}],
#    'place_id': 'ChIJEcySYGJ644kRbWLfuitf5oE',
#    'plus_code': {'compound_code': '8WQX+MJ South Boston, Boston, MA',
#     'global_code': '87JC8WQX+MJ'},
#    'price_level': 1,
#    'rating': 3.6,
#    'reference': 'ChIJEcySYGJ644kRbWLfuitf5oE',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 499,
#    'vicinity': '280 W Broadway, South Boston'}],
#  'status': 'OK'}
